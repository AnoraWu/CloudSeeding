# %%
import pandas as pd
data = pd.read_csv("/Users/anorawu/Documents/GitHub/CloudSeeding/matched_cloud_location_data.csv")

# %%
data
# Out:
#     cloud_optical_thickness  cloud_mask_fraction  latitude_left  \
# 0                 15.098515             1.000000           26.5
# 1                 64.573548             0.998693           35.5
# 2                 25.011019             1.000000           32.5
# 3                 30.072119             1.000000           30.5
# 4                 31.792168             0.984366           32.5
# 5                  6.058000             0.480078           34.5
# 6                 52.728089             0.999314           34.5
# 7                 23.138039             0.985964           25.5
# 8                 20.383227             0.615057           29.5
# 9                  8.018889             0.939178           25.5
# 10                46.441351             1.000000           34.5
# 11                 2.205564             0.587347           34.5
# 12                21.756321             0.999905           34.5
# 13                13.053894             0.516468           34.5
# ...
